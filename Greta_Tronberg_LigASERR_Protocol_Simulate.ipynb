# %% [markdown]
# ## Opentrons - LigASERR protocol
# ---

# %%
from opentrons import simulate

metadata = {'apiLevel': '2.13'}
protocol = simulate.get_protocol_api('2.13')

# Labware
mag_mod = protocol.load_module('Magnetic Module', 1)
mag_plate = mag_mod.load_labware('nest_96_wellplate_200ul_flat')
plate = protocol.load_labware('nest_96_wellplate_200ul_flat', 2)
tips_1 = protocol.load_labware('opentrons_96_tiprack_300ul', 4)
tips_2 = protocol.load_labware('opentrons_96_tiprack_300ul', 5)
reservoir_1 = protocol.load_labware('nest_12_reservoir_15ml', 6)
thermocycler = protocol.load_module('thermocycler')
thermocycler_plate = thermocycler.load_labware('nest_96_wellplate_200ul_flat')
reservoir_2 = protocol.load_labware('nest_12_reservoir_15ml', 9)

# Pipettes
p300 = protocol.load_instrument('p300_multi_gen2', 'left', tip_racks = [tips_1, tips_2])

# TRT reaction
thermocycler.open_lid()
thermocycler.set_block_temperature(25)

thermocycler_top_row = thermocycler_plate.rows()[0]
p300.transfer(80, reservoir_1['A1'], thermocycler_top_row[0], mix_before = (3, 80), blow_out = True, blowout_location = 'destination well', new_tip = 'once')

p300.pick_up_tip()
p300.transfer(80, reservoir_1['A2'], thermocycler_top_row[0], mix_before = (3, 80), mix_after = (3, 80), blow_out = True, blowout_location = 'destination well', new_tip = 'never')
p300.return_tip()

thermocycler.close_lid()

thermocycler.set_lid_temperature(70)
thermocycler.set_block_temperature(37, hold_time_minutes = 30)
thermocycler.set_block_temperature(65, hold_time_minutes = 20)
thermocycler.set_block_temperature(25)
thermocycler.deactivate_lid()
thermocycler.open_lid()

plate_top_row = plate.rows()[0]
p300.pick_up_tip(tips_1['A2'])
p300.transfer(70, thermocycler_top_row[0], plate_top_row[0], mix_before = (3, 70), blow_out = True, blowout_location = 'destination well', new_tip = 'never')
p300.drop_tip()

# Purification of cDNA with SPRI beads
thermocycler.open_lid()
thermocycler.set_block_temperature(25)

p300.pick_up_tip()
p300.transfer(126, reservoir_1['A3'], plate_top_row[0], mix_before = (3, 126), mix_after = (10, 126), blow_out = True, blowout_location = 'destination well', new_tip = 'never')

protocol.delay(minutes = 5)

mag_top_row = mag_plate.rows()[0]
p300.transfer(150, plate_top_row[0], mag_top_row[0], mix_before = (3, 150), blow_out = True, blowout_location = 'destination well', new_tip = 'never')
p300.drop_tip()

mag_mod.engage(height = 11.9)

protocol.delay(minutes = 2)

p300.transfer(130, mag_top_row[0], reservoir_2['A12'], new_tip = 'once')

p300.pick_up_tip()
p300.transfer(180, reservoir_1['A4'], mag_top_row[0], mix_before = (3, 180), air_gap = 10, blow_out = True, blowout_location = 'destination well', new_tip = 'never')

protocol.delay(seconds = 30)

p300.transfer(180, mag_top_row[0], reservoir_2['A12'], air_gap = 10, new_tip = 'never')
p300.drop_tip()

p300.pick_up_tip()
p300.transfer(180, reservoir_1['A4'], mag_top_row[0], mix_before = (3, 180), air_gap = 10, blow_out = True, blowout_location = 'destination well', new_tip = 'never')

protocol.delay(seconds = 30)

p300.transfer(180, mag_top_row[0], reservoir_2['A12'], air_gap = 10, new_tip = 'never')
p300.drop_tip()

mag_mod.disengage()

p300.pick_up_tip()
p300.transfer(180, reservoir_1['A5'], mag_top_row[0], mix_before = (3, 180), mix_after = (10, 180), new_tip = 'never')
p300.transfer(180, mag_top_row[0], plate_top_row[1], blow_out = True, blowout_location = 'destination well', new_tip = 'never')
p300.return_tip()

protocol.delay(minutes = 2)

p300.pick_up_tip(tips_1['A7'])
p300.transfer(150, plate_top_row[1], mag_top_row[1], mix_before = (10, 150), blow_out = True, blowout_location = 'destination well', new_tip = 'never')
p300.drop_tip()

mag_mod.engage(height = 11.9)

protocol.delay(minutes = 1)

p300.transfer(100, mag_top_row[1], thermocycler_top_row[1], blow_out = True, blowout_location = 'destination well', new_tip = 'once')

mag_mod.disengage()

# RNA digestion
thermocycler.open_lid()
thermocycler.set_block_temperature(25)

p300.pick_up_tip()
p300.transfer(50, reservoir_1['A6'], thermocycler_top_row[1], mix_before = (3, 50), mix_after = (3, 50), blow_out = True, blowout_location = 'destination well', new_tip = 'never')
p300.return_tip()

thermocycler.close_lid()

thermocycler.set_lid_temperature(70)
thermocycler.set_block_temperature(37, hold_time_minutes = 30)
thermocycler.deactivate_lid()
thermocycler.set_block_temperature(4)
thermocycler.open_lid()

p300.pick_up_tip(tips_1['A9'])
p300.transfer(55, thermocycler_top_row[1], thermocycler_top_row[2], blow_out = True, blowout_location = 'destination well', new_tip = 'never')
p300.drop_tip()

p300.home()

protocol.set_rail_lights(True)

protocol.pause('Please add Ligase Reaction Mix to Reservoir-1 A7, and NEB Taq DNA ligase to Reservoir-1 A8.')

# Annealing and Ligation Reaction for cDNA
thermocycler.open_lid()

protocol.set_rail_lights(False)

thermocycler.set_block_temperature(4)

p300.transfer(25, reservoir_1['A7'], thermocycler_top_row[2], mix_before = (3, 25), mix_after = (3, 25), blow_out = True, blowout_location = 'destination well', new_tip = 'once')

p300.pick_up_tip()
p300.transfer(20, reservoir_1['A8'], thermocycler_top_row[2], mix_before = (3, 20), mix_after = (3, 20), new_tip = 'never')
p300.transfer(90, thermocycler_top_row[2], thermocycler_top_row[3], blow_out = True, blowout_location = 'destination well', new_tip = 'never')
p300.drop_tip()

thermocycler.close_lid()

thermocycler.set_lid_temperature(70)
thermocycler.set_block_temperature(51.7, hold_time_minutes = 30)    # for full-length cDNA (or 46.4C for cleaved cDNA)
thermocycler.set_block_temperature(25)
thermocycler.deactivate_lid()
thermocycler.open_lid()

p300.pick_up_tip()
p300.transfer(30, reservoir_1['A9'], thermocycler_top_row[3], mix_before = (3, 30), mix_after = (3, 30), new_tip = 'never')
p300.transfer(100, thermocycler_top_row[3], plate_top_row[2], blow_out = True, blowout_location = 'destination well', new_tip = 'never')
p300.drop_tip()

# Purification of cDNA with Dynabeads
p300.transfer(50, reservoir_1['A10'], mag_top_row[2], mix_before = (3, 50), blow_out = True, blowout_location = 'destination well', new_tip = 'once')

for i in range(2):
    p300.pick_up_tip()
    p300.transfer(150, reservoir_1['A11'], mag_top_row[2], mix_before = (3, 150), mix_after = (3, 150), blow_out = True, blowout_location = 'destination well', new_tip = 'never')
    
    mag_mod.engage(height = 11.9)
    
    protocol.delay(minutes = 2)

    p300.transfer(150, mag_top_row[2], reservoir_2['A12'], new_tip = 'never')
    p300.drop_tip()
    
    mag_mod.disengage()

p300.pick_up_tip()
p300.transfer(150, reservoir_1['A12'], mag_top_row[2], mix_before = (3, 150), mix_after = (3, 150), blow_out = True, blowout_location = 'destination well', new_tip = 'never')

mag_mod.engage(height = 11.9)

protocol.delay(minutes = 2)

p300.transfer(150, mag_top_row[2], reservoir_2['A12'], new_tip = 'never')
p300.drop_tip()

mag_mod.disengage()

p300.pick_up_tip()
p300.transfer(150, reservoir_1['A12'], mag_top_row[2], mix_before = (3, 150), mix_after = (10, 150), new_tip = 'never')
p300.transfer(100, mag_top_row[2], plate_top_row[2], mix_after = (3, 100), blow_out = True, blowout_location = 'destination well', new_tip = 'never')

for i in range(10):
    protocol.delay(seconds = 75)
    
    p300.mix(10, 100, plate_top_row[2])
    p300.blow_out(plate_top_row[2])

p300.transfer(150, plate_top_row[2], mag_top_row[3], mix_before = (10, 150), blow_out = True, blowout_location = 'destination well', new_tip = 'never')

mag_mod.engage(height = 11.9)

protocol.delay(minutes = 3)

p300.transfer(130, mag_top_row[3], reservoir_2['A12'], new_tip = 'never')
p300.drop_tip()

for i in range(2):
    p300.pick_up_tip()
    p300.transfer(180, reservoir_1['A11'], mag_top_row[3], mix_before = (3, 180), blow_out = True, blowout_location = 'destination well', new_tip = 'never')

    protocol.delay(seconds = 30)

    p300.transfer(180, mag_top_row[3], reservoir_2['A12'], new_tip = 'never')
    p300.drop_tip()

p300.pick_up_tip()
p300.transfer(180, reservoir_1['A11'], mag_top_row[3], mix_before = (3, 180), blow_out = True, blowout_location = 'destination well', new_tip = 'never')

protocol.delay(seconds = 30)

p300.transfer(200, mag_top_row[3], reservoir_2['A12'], new_tip = 'never')
p300.drop_tip()

mag_mod.disengage()

p300.pick_up_tip()
p300.transfer(200, reservoir_2['A1'], mag_top_row[3], mix_before = (3, 200), mix_after = (10, 150), new_tip = 'never')
p300.transfer(150, mag_top_row[3], thermocycler_top_row[4], blow_out = True, blowout_location = 'destination well', new_tip = 'never')
p300.drop_tip()

# Print commands for simulation check
for line in protocol.commands():
    print(line)
# Out:
# C:\Users\Athena Wu\.opentrons\robot_settings.json not found. Loading defaults
# C:\Users\Athena Wu\.opentrons\deck_calibration.json not found. Loading defaults
# This labware ({}) is not explicitly compatible with the Magnetic Module. You will have to specify a height when calling engage().
# Opening Thermocycler lid
# Moving to (347.84000000000003, 351.5, 253.52)
# Setting Thermocycler well block temperature to 25.0 °C
# Transferring 80.0 from A1 of NEST 12 Well Reservoir 15 mL on 6 to A1 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 4
# Mixing 3 times with a volume of 80.0 ul
# Aspirating 80.0 uL from A1 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 80.0 uL into A1 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 80.0 uL from A1 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 80.0 uL into A1 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 80.0 uL from A1 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 80.0 uL into A1 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 80.0 uL from A1 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 80.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Blowing out at A1 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 4
# Transferring 80.0 from A2 of NEST 12 Well Reservoir 15 mL on 6 to A1 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7
# Mixing 3 times with a volume of 80.0 ul
# Aspirating 80.0 uL from A2 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 80.0 uL into A2 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 80.0 uL from A2 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 80.0 uL into A2 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 80.0 uL from A2 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 80.0 uL into A2 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 80.0 uL from A2 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 80.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Mixing 3 times with a volume of 80.0 ul
# Aspirating 80.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Dispensing 80.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Aspirating 80.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Dispensing 80.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Aspirating 80.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Dispensing 80.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Blowing out at A1 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7
# Returning tip
# Dropping tip into A2 of Opentrons 96 Tip Rack 300 µL on 4
# Closing Thermocycler lid
# Moving to (347.84000000000003, 351.5, 253.52)
# Setting Thermocycler lid temperature to 70.0 °C
# Setting Thermocycler well block temperature to 37.0 °C with a hold time of 30.0 minutes and 0 seconds
# Setting Thermocycler well block temperature to 65.0 °C with a hold time of 20.0 minutes and 0 seconds
# Setting Thermocycler well block temperature to 25.0 °C
# Deactivating Thermocycler lid heating
# Opening Thermocycler lid
# Moving to (347.84000000000003, 351.5, 253.52)
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 4
# Transferring 70.0 from A1 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 to A1 of NEST 96 Well Plate 200 µL Flat on 2
# Mixing 3 times with a volume of 70.0 ul
# Aspirating 70.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Dispensing 70.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Aspirating 70.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Dispensing 70.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Aspirating 70.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Dispensing 70.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Aspirating 70.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Dispensing 70.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Blowing out at A1 of NEST 96 Well Plate 200 µL Flat on 2
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Opening Thermocycler lid
# Moving to (347.84000000000003, 351.5, 253.52)
# Setting Thermocycler well block temperature to 25.0 °C
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 4
# Transferring 126.0 from A3 of NEST 12 Well Reservoir 15 mL on 6 to A1 of NEST 96 Well Plate 200 µL Flat on 2
# Mixing 3 times with a volume of 126.0 ul
# Aspirating 126.0 uL from A3 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 126.0 uL into A3 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 126.0 uL from A3 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 126.0 uL into A3 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 126.0 uL from A3 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 126.0 uL into A3 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 126.0 uL from A3 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 126.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Mixing 10 times with a volume of 126.0 ul
# Aspirating 126.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 126.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 126.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 126.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 126.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 126.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 126.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 126.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 126.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 126.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 126.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 126.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 126.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 126.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 126.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 126.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 126.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 126.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 126.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 126.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Blowing out at A1 of NEST 96 Well Plate 200 µL Flat on 2
# Delaying for 5 minutes and 0.0 seconds
# Transferring 150.0 from A1 of NEST 96 Well Plate 200 µL Flat on 2 to A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1
# Mixing 3 times with a volume of 150.0 ul
# Aspirating 150.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 150.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 150.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 150.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 150.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 150.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 150.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 150.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Blowing out at A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Engaging Magnetic Module
# Delaying for 2 minutes and 0.0 seconds
# Transferring 130.0 from A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 to A12 of NEST 12 Well Reservoir 15 mL on 9
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 4
# Aspirating 130.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 130.0 uL into A12 of NEST 12 Well Reservoir 15 mL on 9 at 94.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from A5 of Opentrons 96 Tip Rack 300 µL on 4
# Transferring 180.0 from A4 of NEST 12 Well Reservoir 15 mL on 6 to A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1
# Mixing 3 times with a volume of 180.0 ul
# Aspirating 180.0 uL from A4 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 180.0 uL into A4 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 180.0 uL from A4 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 180.0 uL into A4 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 180.0 uL from A4 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 180.0 uL into A4 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 180.0 uL from A4 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Air gap
# Aspirating 10.0 uL from A4 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 190.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Blowing out at A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1
# Delaying for 0 minutes and 30.0 seconds
# Transferring 180.0 from A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 to A12 of NEST 12 Well Reservoir 15 mL on 9
# Aspirating 180.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Air gap
# Aspirating 10.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 190.0 uL into A12 of NEST 12 Well Reservoir 15 mL on 9 at 94.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from A6 of Opentrons 96 Tip Rack 300 µL on 4
# Transferring 180.0 from A4 of NEST 12 Well Reservoir 15 mL on 6 to A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1
# Mixing 3 times with a volume of 180.0 ul
# Aspirating 180.0 uL from A4 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 180.0 uL into A4 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 180.0 uL from A4 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 180.0 uL into A4 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 180.0 uL from A4 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 180.0 uL into A4 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 180.0 uL from A4 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Air gap
# Aspirating 10.0 uL from A4 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 190.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Blowing out at A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1
# Delaying for 0 minutes and 30.0 seconds
# Transferring 180.0 from A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 to A12 of NEST 12 Well Reservoir 15 mL on 9
# Aspirating 180.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Air gap
# Aspirating 10.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 190.0 uL into A12 of NEST 12 Well Reservoir 15 mL on 9 at 94.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Disengaging Magnetic Module
# Picking up tip from A7 of Opentrons 96 Tip Rack 300 µL on 4
# Transferring 180.0 from A5 of NEST 12 Well Reservoir 15 mL on 6 to A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1
# Mixing 3 times with a volume of 180.0 ul
# Aspirating 180.0 uL from A5 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 180.0 uL into A5 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 180.0 uL from A5 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 180.0 uL into A5 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 180.0 uL from A5 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 180.0 uL into A5 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 180.0 uL from A5 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 180.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Mixing 10 times with a volume of 180.0 ul
# Aspirating 180.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 180.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 180.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 180.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 180.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 180.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 180.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 180.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 180.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 180.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 180.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 180.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 180.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 180.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 180.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 180.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 180.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 180.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 180.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 180.0 uL into A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Transferring 180.0 from A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 to A2 of NEST 96 Well Plate 200 µL Flat on 2
# Aspirating 180.0 uL from A1 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 180.0 uL into A2 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Blowing out at A2 of NEST 96 Well Plate 200 µL Flat on 2
# Returning tip
# Dropping tip into A7 of Opentrons 96 Tip Rack 300 µL on 4
# Delaying for 2 minutes and 0.0 seconds
# Picking up tip from A7 of Opentrons 96 Tip Rack 300 µL on 4
# Transferring 150.0 from A2 of NEST 96 Well Plate 200 µL Flat on 2 to A2 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1
# Mixing 10 times with a volume of 150.0 ul
# Aspirating 150.0 uL from A2 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 150.0 uL into A2 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 150.0 uL from A2 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 150.0 uL into A2 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 150.0 uL from A2 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 150.0 uL into A2 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 150.0 uL from A2 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 150.0 uL into A2 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 150.0 uL from A2 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 150.0 uL into A2 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 150.0 uL from A2 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 150.0 uL into A2 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 150.0 uL from A2 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 150.0 uL into A2 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 150.0 uL from A2 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 150.0 uL into A2 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 150.0 uL from A2 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 150.0 uL into A2 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 150.0 uL from A2 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 150.0 uL into A2 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 150.0 uL from A2 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 150.0 uL into A2 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Blowing out at A2 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Engaging Magnetic Module
# Delaying for 1 minutes and 0.0 seconds
# Transferring 100.0 from A2 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 to A2 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7
# Picking up tip from A8 of Opentrons 96 Tip Rack 300 µL on 4
# Aspirating 100.0 uL from A2 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 100.0 uL into A2 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Blowing out at A2 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Disengaging Magnetic Module
# Opening Thermocycler lid
# Moving to (347.84000000000003, 351.5, 253.52)
# Setting Thermocycler well block temperature to 25.0 °C
# Picking up tip from A9 of Opentrons 96 Tip Rack 300 µL on 4
# Transferring 50.0 from A6 of NEST 12 Well Reservoir 15 mL on 6 to A2 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from A6 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 50.0 uL into A6 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 50.0 uL from A6 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 50.0 uL into A6 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 50.0 uL from A6 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 50.0 uL into A6 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 50.0 uL from A6 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 50.0 uL into A2 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from A2 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Dispensing 50.0 uL into A2 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Aspirating 50.0 uL from A2 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Dispensing 50.0 uL into A2 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Aspirating 50.0 uL from A2 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Dispensing 50.0 uL into A2 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Blowing out at A2 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7
# Returning tip
# Dropping tip into A9 of Opentrons 96 Tip Rack 300 µL on 4
# Closing Thermocycler lid
# Moving to (347.84000000000003, 351.5, 253.52)
# Setting Thermocycler lid temperature to 70.0 °C
# Setting Thermocycler well block temperature to 37.0 °C with a hold time of 30.0 minutes and 0 seconds
# Deactivating Thermocycler lid heating
# Setting Thermocycler well block temperature to 4.0 °C
# Opening Thermocycler lid
# Moving to (347.84000000000003, 351.5, 253.52)
# Picking up tip from A9 of Opentrons 96 Tip Rack 300 µL on 4
# Transferring 55.0 from A2 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 to A3 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7
# Aspirating 55.0 uL from A2 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Dispensing 55.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Blowing out at A3 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Homing pipette plunger on mount left
# Pausing robot operation: Please add Ligase Reaction Mix to Reservoir-1 A7, and NEB Taq DNA ligase to Reservoir-1 A8.
# Opening Thermocycler lid
# Moving to (347.84000000000003, 351.5, 253.52)
# Setting Thermocycler well block temperature to 4.0 °C
# Transferring 25.0 from A7 of NEST 12 Well Reservoir 15 mL on 6 to A3 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7
# Picking up tip from A10 of Opentrons 96 Tip Rack 300 µL on 4
# Mixing 3 times with a volume of 25.0 ul
# Aspirating 25.0 uL from A7 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 25.0 uL into A7 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 25.0 uL from A7 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 25.0 uL into A7 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 25.0 uL from A7 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 25.0 uL into A7 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 25.0 uL from A7 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 25.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Mixing 3 times with a volume of 25.0 ul
# Aspirating 25.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Dispensing 25.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Aspirating 25.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Dispensing 25.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Aspirating 25.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Dispensing 25.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Blowing out at A3 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from A11 of Opentrons 96 Tip Rack 300 µL on 4
# Transferring 20.0 from A8 of NEST 12 Well Reservoir 15 mL on 6 to A3 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7
# Mixing 3 times with a volume of 20.0 ul
# Aspirating 20.0 uL from A8 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 20.0 uL into A8 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 20.0 uL from A8 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 20.0 uL into A8 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 20.0 uL from A8 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 20.0 uL into A8 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 20.0 uL from A8 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 20.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Mixing 3 times with a volume of 20.0 ul
# Aspirating 20.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Dispensing 20.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Aspirating 20.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Dispensing 20.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Aspirating 20.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Dispensing 20.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Transferring 90.0 from A3 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 to A4 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7
# Aspirating 90.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Dispensing 90.0 uL into A4 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Blowing out at A4 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Closing Thermocycler lid
# Moving to (347.84000000000003, 351.5, 253.52)
# Setting Thermocycler lid temperature to 70.0 °C
# Setting Thermocycler well block temperature to 51.7 °C with a hold time of 30.0 minutes and 0 seconds
# Setting Thermocycler well block temperature to 25.0 °C
# Deactivating Thermocycler lid heating
# Opening Thermocycler lid
# Moving to (347.84000000000003, 351.5, 253.52)
# Picking up tip from A12 of Opentrons 96 Tip Rack 300 µL on 4
# Transferring 30.0 from A9 of NEST 12 Well Reservoir 15 mL on 6 to A4 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7
# Mixing 3 times with a volume of 30.0 ul
# Aspirating 30.0 uL from A9 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 30.0 uL into A9 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 30.0 uL from A9 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 30.0 uL into A9 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 30.0 uL from A9 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 30.0 uL into A9 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 30.0 uL from A9 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 30.0 uL into A4 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Mixing 3 times with a volume of 30.0 ul
# Aspirating 30.0 uL from A4 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Dispensing 30.0 uL into A4 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Aspirating 30.0 uL from A4 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Dispensing 30.0 uL into A4 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Aspirating 30.0 uL from A4 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Dispensing 30.0 uL into A4 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Transferring 100.0 from A4 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 to A3 of NEST 96 Well Plate 200 µL Flat on 2
# Aspirating 100.0 uL from A4 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Blowing out at A3 of NEST 96 Well Plate 200 µL Flat on 2
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Transferring 50.0 from A10 of NEST 12 Well Reservoir 15 mL on 6 to A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 5
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from A10 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 50.0 uL into A10 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 50.0 uL from A10 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 50.0 uL into A10 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 50.0 uL from A10 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 50.0 uL into A10 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 50.0 uL from A10 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 50.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Blowing out at A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 5
# Transferring 150.0 from A11 of NEST 12 Well Reservoir 15 mL on 6 to A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1
# Mixing 3 times with a volume of 150.0 ul
# Aspirating 150.0 uL from A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 150.0 uL into A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 150.0 uL from A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 150.0 uL into A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 150.0 uL from A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 150.0 uL into A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 150.0 uL from A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Mixing 3 times with a volume of 150.0 ul
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Blowing out at A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1
# Engaging Magnetic Module
# Delaying for 2 minutes and 0.0 seconds
# Transferring 150.0 from A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 to A12 of NEST 12 Well Reservoir 15 mL on 9
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A12 of NEST 12 Well Reservoir 15 mL on 9 at 94.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Disengaging Magnetic Module
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 5
# Transferring 150.0 from A11 of NEST 12 Well Reservoir 15 mL on 6 to A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1
# Mixing 3 times with a volume of 150.0 ul
# Aspirating 150.0 uL from A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 150.0 uL into A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 150.0 uL from A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 150.0 uL into A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 150.0 uL from A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 150.0 uL into A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 150.0 uL from A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Mixing 3 times with a volume of 150.0 ul
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Blowing out at A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1
# Engaging Magnetic Module
# Delaying for 2 minutes and 0.0 seconds
# Transferring 150.0 from A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 to A12 of NEST 12 Well Reservoir 15 mL on 9
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A12 of NEST 12 Well Reservoir 15 mL on 9 at 94.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Disengaging Magnetic Module
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 5
# Transferring 150.0 from A12 of NEST 12 Well Reservoir 15 mL on 6 to A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1
# Mixing 3 times with a volume of 150.0 ul
# Aspirating 150.0 uL from A12 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 150.0 uL into A12 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 150.0 uL from A12 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 150.0 uL into A12 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 150.0 uL from A12 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 150.0 uL into A12 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 150.0 uL from A12 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Mixing 3 times with a volume of 150.0 ul
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Blowing out at A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1
# Engaging Magnetic Module
# Delaying for 2 minutes and 0.0 seconds
# Transferring 150.0 from A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 to A12 of NEST 12 Well Reservoir 15 mL on 9
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A12 of NEST 12 Well Reservoir 15 mL on 9 at 94.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Disengaging Magnetic Module
# Picking up tip from A5 of Opentrons 96 Tip Rack 300 µL on 5
# Transferring 150.0 from A12 of NEST 12 Well Reservoir 15 mL on 6 to A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1
# Mixing 3 times with a volume of 150.0 ul
# Aspirating 150.0 uL from A12 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 150.0 uL into A12 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 150.0 uL from A12 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 150.0 uL into A12 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 150.0 uL from A12 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 150.0 uL into A12 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 150.0 uL from A12 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Mixing 10 times with a volume of 150.0 ul
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Transferring 100.0 from A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 to A3 of NEST 96 Well Plate 200 µL Flat on 2
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Mixing 3 times with a volume of 100.0 ul
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Blowing out at A3 of NEST 96 Well Plate 200 µL Flat on 2
# Delaying for 1 minutes and 15.0 seconds
# Mixing 10 times with a volume of 100.0 ul
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Blowing out at A3 of NEST 96 Well Plate 200 µL Flat on 2
# Delaying for 1 minutes and 15.0 seconds
# Mixing 10 times with a volume of 100.0 ul
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Blowing out at A3 of NEST 96 Well Plate 200 µL Flat on 2
# Delaying for 1 minutes and 15.0 seconds
# Mixing 10 times with a volume of 100.0 ul
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Blowing out at A3 of NEST 96 Well Plate 200 µL Flat on 2
# Delaying for 1 minutes and 15.0 seconds
# Mixing 10 times with a volume of 100.0 ul
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Blowing out at A3 of NEST 96 Well Plate 200 µL Flat on 2
# Delaying for 1 minutes and 15.0 seconds
# Mixing 10 times with a volume of 100.0 ul
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# ...
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Blowing out at A3 of NEST 96 Well Plate 200 µL Flat on 2
# Delaying for 1 minutes and 15.0 seconds
# Mixing 10 times with a volume of 100.0 ul
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Blowing out at A3 of NEST 96 Well Plate 200 µL Flat on 2
# Delaying for 1 minutes and 15.0 seconds
# Mixing 10 times with a volume of 100.0 ul
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Blowing out at A3 of NEST 96 Well Plate 200 µL Flat on 2
# Delaying for 1 minutes and 15.0 seconds
# Mixing 10 times with a volume of 100.0 ul
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 100.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 100.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Blowing out at A3 of NEST 96 Well Plate 200 µL Flat on 2
# Transferring 150.0 from A3 of NEST 96 Well Plate 200 µL Flat on 2 to A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1
# Mixing 10 times with a volume of 150.0 ul
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 150.0 uL into A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Aspirating 150.0 uL from A3 of NEST 96 Well Plate 200 µL Flat on 2 at 94.0 uL/sec
# Dispensing 150.0 uL into A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Blowing out at A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1
# Engaging Magnetic Module
# Delaying for 3 minutes and 0.0 seconds
# Transferring 130.0 from A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 to A12 of NEST 12 Well Reservoir 15 mL on 9
# Aspirating 130.0 uL from A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 130.0 uL into A12 of NEST 12 Well Reservoir 15 mL on 9 at 94.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from A6 of Opentrons 96 Tip Rack 300 µL on 5
# Transferring 180.0 from A11 of NEST 12 Well Reservoir 15 mL on 6 to A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1
# Mixing 3 times with a volume of 180.0 ul
# Aspirating 180.0 uL from A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 180.0 uL into A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 180.0 uL from A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 180.0 uL into A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 180.0 uL from A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 180.0 uL into A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 180.0 uL from A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 180.0 uL into A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Blowing out at A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1
# Delaying for 0 minutes and 30.0 seconds
# Transferring 180.0 from A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 to A12 of NEST 12 Well Reservoir 15 mL on 9
# Aspirating 180.0 uL from A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 180.0 uL into A12 of NEST 12 Well Reservoir 15 mL on 9 at 94.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from A7 of Opentrons 96 Tip Rack 300 µL on 5
# Transferring 180.0 from A11 of NEST 12 Well Reservoir 15 mL on 6 to A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1
# Mixing 3 times with a volume of 180.0 ul
# Aspirating 180.0 uL from A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 180.0 uL into A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 180.0 uL from A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 180.0 uL into A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 180.0 uL from A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 180.0 uL into A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 180.0 uL from A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 180.0 uL into A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Blowing out at A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1
# Delaying for 0 minutes and 30.0 seconds
# Transferring 180.0 from A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 to A12 of NEST 12 Well Reservoir 15 mL on 9
# Aspirating 180.0 uL from A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 180.0 uL into A12 of NEST 12 Well Reservoir 15 mL on 9 at 94.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from A8 of Opentrons 96 Tip Rack 300 µL on 5
# Transferring 180.0 from A11 of NEST 12 Well Reservoir 15 mL on 6 to A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1
# Mixing 3 times with a volume of 180.0 ul
# Aspirating 180.0 uL from A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 180.0 uL into A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 180.0 uL from A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 180.0 uL into A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 180.0 uL from A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 180.0 uL into A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Aspirating 180.0 uL from A11 of NEST 12 Well Reservoir 15 mL on 6 at 94.0 uL/sec
# Dispensing 180.0 uL into A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Blowing out at A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1
# Delaying for 0 minutes and 30.0 seconds
# Transferring 200.0 from A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 to A12 of NEST 12 Well Reservoir 15 mL on 9
# Aspirating 200.0 uL from A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 200.0 uL into A12 of NEST 12 Well Reservoir 15 mL on 9 at 94.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Disengaging Magnetic Module
# Picking up tip from A9 of Opentrons 96 Tip Rack 300 µL on 5
# Transferring 200.0 from A1 of NEST 12 Well Reservoir 15 mL on 9 to A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1
# Mixing 3 times with a volume of 200.0 ul
# Aspirating 200.0 uL from A1 of NEST 12 Well Reservoir 15 mL on 9 at 94.0 uL/sec
# Dispensing 200.0 uL into A1 of NEST 12 Well Reservoir 15 mL on 9 at 94.0 uL/sec
# Aspirating 200.0 uL from A1 of NEST 12 Well Reservoir 15 mL on 9 at 94.0 uL/sec
# Dispensing 200.0 uL into A1 of NEST 12 Well Reservoir 15 mL on 9 at 94.0 uL/sec
# Aspirating 200.0 uL from A1 of NEST 12 Well Reservoir 15 mL on 9 at 94.0 uL/sec
# Dispensing 200.0 uL into A1 of NEST 12 Well Reservoir 15 mL on 9 at 94.0 uL/sec
# Aspirating 200.0 uL from A1 of NEST 12 Well Reservoir 15 mL on 9 at 94.0 uL/sec
# Dispensing 200.0 uL into A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Mixing 10 times with a volume of 150.0 ul
# Aspirating 150.0 uL from A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 150.0 uL from A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 150.0 uL from A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 150.0 uL from A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 150.0 uL from A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 150.0 uL from A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 150.0 uL from A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 150.0 uL from A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 150.0 uL from A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Aspirating 150.0 uL from A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Transferring 150.0 from A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 to A5 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7
# Aspirating 150.0 uL from A4 of NEST 96 Well Plate 200 µL Flat on Magnetic Module GEN1 on 1 at 94.0 uL/sec
# Dispensing 150.0 uL into A5 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7 at 94.0 uL/sec
# Blowing out at A5 of NEST 96 Well Plate 200 µL Flat on Thermocycler Module on 7
# Dropping tip into A1 of Opentrons Fixed Trash on 12
